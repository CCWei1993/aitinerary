# %%
import requests
import json
import statistics
# food variables: 
# age(年齡), been2tko(旅遊次數), days(旅遊天數) , totalBudget(總預算), gender(性別 - 0:男  1:女), oneBudget(一餐預算)
req = requests.post('http://127.0.0.1:5009/',
                    json = {'age':20,'been2tko':1,'days':6,'totalBudget':107000,'gender':0, 'oneBudget':300}).json()
#req = requests.post('http://127.0.0.1:5000/')
print(len(req),type(req),req)
print()
print('讓您久等了，最適合您的餐廳如下列：\n'+
      str(req[0]['store_nm_jp'])+'，在地評價為'+str(req[0]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[0]['rest_catg'])+
      '，用餐需時約'+str(req[0]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[0]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[0]['prices_dinner'])+
      '\n地址為'+
      str(req[0]['rest_addr'])+
      '\n\n'+
      str(req[1]['store_nm_jp'])+'，在地評價為'+str(req[1]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[1]['rest_catg'])+
      '，用餐需時約'+str(req[1]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[1]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[1]['prices_dinner'])+
      '\n地址為'+
      str(req[1]['rest_addr'])+
     '\n\n'+
      str(req[2]['store_nm_jp'])+'，在地評價為'+str(req[2]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[2]['rest_catg'])+
      '，用餐需時約'+str(req[2]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[2]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[2]['prices_dinner'])+
      '\n地址為'+
      str(req[2]['rest_addr'])+
     '\n\n'+
      str(req[3]['store_nm_jp'])+'，在地評價為'+str(req[3]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[3]['rest_catg'])+
      '，用餐需時約'+str(req[3]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[3]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[3]['prices_dinner'])+
      '\n地址為'+
      str(req[3]['rest_addr'])+
     '\n\n'+
      str(req[4]['store_nm_jp'])+'，在地評價為'+str(req[4]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[4]['rest_catg'])+
      '，用餐需時約'+str(req[4]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[4]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[4]['prices_dinner'])+
      '\n地址為'+
      str(req[4]['rest_addr'])+
     '\n\n'+
      str(req[5]['store_nm_jp'])+'，在地評價為'+str(req[5]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[5]['rest_catg'])+
      '，用餐需時約'+str(req[5]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[5]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[5]['prices_dinner'])+
      '\n地址為'+
      str(req[5]['rest_addr'])+
     '\n\n'+
      str(req[6]['store_nm_jp'])+'，在地評價為'+str(req[4]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[6]['rest_catg'])+
      '，用餐需時約'+str(req[6]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[6]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[6]['prices_dinner'])+
      '\n地址為'+
      str(req[6]['rest_addr'])+
     '\n\n'+
      str(req[7]['store_nm_jp'])+'，在地評價為'+str(req[4]['rest_rating'])+'顆星'+
      '\n餐飲型態為'+str(req[7]['rest_catg'])+
      '，用餐需時約'+str(req[7]['meal_duration'])+
      '小時\n參考價格為午餐NTD$'+
      str(req[7]['prices_lunch'])+
      '\n晚餐NTD$'+
      str(req[7]['prices_dinner'])+
      '\n地址為'+
      str(req[7]['rest_addr']))
# Out:
# 12 <class 'list'> [{'age': 35, 'cp_rating_dinner': 4.1, 'cp_rating_lunch': 4.35, 'feeling_rating_dinner': 4.05, 'feeling_rating_lunch': 4.49, 'female_prop': 24.11, 'label_code': 0, 'label_desc': '高消族', 'lat': 35.6648568, 'lng': 139.7323448, 'male_prop': 75.89, 'meal_duration': 1.0, 'prices_dinner': 7087, 'prices_lunch': 425, 'rest_addr': '東京都港區六本木4-5-11', 'rest_area': '六本木・乃木坂・西麻布', 'rest_catg': '壽司', 'rest_rating': 4.08, 'service_rating_dinner': 4.17, 'service_rating_lunch': 4.69, 'store_nm_en': 'Yu', 'store_nm_jp': '鮨 由う', 'transport': '日比谷線\u3000六本木駅 4a出口から徒歩4分\n大江戸線\u3000六本木駅 6番出口から徒歩3分 \n千代田線\u3000乃木坂駅 3番出口から徒歩8分 \n◇六本木交差点からミッドタウンに向かい進行方向右手側の【小諸そば】を右折し直進1つ目の十字路を過ぎると左正面に【听屋（POUND‐YA） 六本木】がございますのでそこを左折し5ⅿ程で右手側に当店がございます。\n\n\n距离六本木 247  米'}, {'age': 37, 'cp_rating_dinner': 3.49, 'cp_rating_lunch': 3.64, 'feeling_rating_dinner': 4.2, 'feeling_rating_lunch': 4.27, 'female_prop': 24.16, 'label_code': 0, 'label_desc': '高消族', 'lat': 35.6799926, 'lng': 139.7379363, 'male_prop': 75.84, 'm
# ...

# %%
rest_welcome='讓您久等了，最適合您的餐廳如下列：\n'
resttext_list=[]
for i in range(0,14):
    rest_text=(str(req[i]['store_nm_jp'])+
          '，在地評價為'+
          str(req[i]['rest_rating'])+
          '顆星'+
          '\n餐飲型態為'+str(req[i]['rest_catg'])+
          '，用餐需時約'+str(req[i]['meal_duration'])+
          '小時\n參考價格為午餐NTD$'+
          str(req[i]['prices_lunch'])+
          '\n晚餐NTD$'+
          str(req[i]['prices_dinner'])+
              '\n地址為'+
              str(req[i]['rest_addr'])+'\n')
    resttext_list.append(rest_text)
print(rest_welcome,
      resttext_list[0],
      resttext_list[1],
      resttext_list[2],
      resttext_list[3],
      resttext_list[4],
      resttext_list[5],
      resttext_list[6],
      resttext_list[7],
      resttext_list[8])
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-2-355e59df3b50> in <module>
#      13           str(req[i]['prices_dinner'])+
#      14               '\n地址為'+
# ---> 15               str(req[i]['rest_addr'])+'\n')
#      16     resttext_list.append(rest_text)
#      17 print(rest_welcome,
#
# IndexError: list index out of range

# %%
s=''
print(len(req),type(req))
print('讓您久等了，最適合您的餐廳如下列：\n')
for i in req:
    rest_text=(str(i['store_nm_jp'])+
          '，在地評價為'+
          str(i['rest_rating'])+
          '顆星'+
          '\n餐飲型態為'+str(i['rest_catg'])+
          '，用餐需時約'+str(i['meal_duration'])+
          '小時\n參考價格為午餐NTD$'+
          str(i['prices_lunch'])+
          '\n晚餐NTD$'+
          str(i['prices_dinner'])+
              '\n地址為'+
              str(i['rest_addr'])+'\n\n')
    s+=rest_text
print(s)
