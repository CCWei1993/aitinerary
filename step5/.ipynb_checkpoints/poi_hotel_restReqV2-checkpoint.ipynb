# %%
#!pip install -U googlemaps
#!pip install gmaps
#!pip install networkx
import requests
import json
import pandas as pd
import googlemaps
import gmaps
from ipywidgets.embed import embed_minimal_html


#request pois & hotel
req = requests.post('http://127.0.0.1:5007/',
                    json = {'age':20,'been2tko':6,'howlong':5,'budget':50000,
                            'isFemale':1,'with_child':0,'crampedSechedule':True}
                   )
req.encoding='utf-8'
req = req.json()

reqH = requests.post('http://127.0.0.1:5008/', json = {'age':20,'been2tko':5,'days':0,
                                                      'budget':50000,'isFemale':1,'hotel budget':3000}).json()

reqR = requests.post('http://127.0.0.1:5009/',
                    json = {'age':20,'been2tko':5,'days':0,'totalBudget':50000,'gender':1, 'oneBudget':300}).json()
#req = requests.post('http://127.0.0.1:5000/')
print(len(req),type(req),req,len(reqH),type(reqH),reqH, len(reqR),type(reqR),reqR,sep='\n')
# print(req.content.decode('utf-8'))
# Out:
# 5
# <class 'list'>
# ['[{"index":2,"name":"淺草 Asakusa","rank":"排名第 1的台東區觀光 (共560家)","address":"東京都台東區","child":0.0087715012,"latitude":35.7125736,"longitude":139.7802043,"score":241,"chosen":true},{"index":48,"name":"雷門 Nakamise Shopping Street (Kaminarimon)","rank":"排名第 18的台東區觀光 (共560家)","address":"東京都台東區淺草1丁目3","child":0.0048539208,"latitude":35.7110859,"longitude":139.7959648,"score":114,"chosen":true},{"index":35,"name":"淺草文化觀光中心 Asakusa Culture Tourist Information Center","rank":"排名第 3的台東區觀光 (共560家)","address":"東京都台東區2-18-9 Kaminarimon111-0034","child":0.0040560983,"latitude":35.7106489,"longitude":139.7965348,"score":106,"chosen":true},{"index":8,"name":"晴空塔 Tokyo Skytree","rank":"排名第 3的墨田區觀光 (共264家)","address":"東京都墨田區1-1-2 Oshiage131-0045","child":0.0163115893,"latitude":35.7283756,"longitude":139.8135673,"score":84,"chosen":true}]', '[{"index":265,"name":"東京迪士尼海洋樂園 Tokyo DisneySea","rank":"排名第 1的Maihama觀光 (共5家)","address":"千葉縣浦安Maihama1-13279-0031","child":0.75,"latitude":35.62675,"longitude":139.885095,"score":94,"chosen":true}]', '[{"index":192,"name":"隅田川花火大會 Sumida River Fireworks","rank":"排名第 12的墨田區觀光 (共264家)","address":"東京都墨田區","child":0.0,"latitude":35.7107479,"longitude":139.8016393,"score":70,"chosen":true},{"index":260,"name":"板橋花火節 Itabashi Fireworks","rank":"排名第 1的板橋區觀光 (共81家)","address":"東京都板橋區4 Funado174-0041","child":0.0,"latitude":35.7512308,"longitude":139.7185838,"score":70,"chosen":true},{"index":193,"name":"大江戶古董市場 - 東京國際論壇 Oedo Antique Market - Tokyo International Forum","rank":"排名第 55的千代田區觀光 (共446家)","address":"東京都千代田區3-5-1 MarunouchiTokyo International Forum100-0005","child":0.0199828611,"latitude":35.6767429,"longitude":139.7637532,"score":84,"chosen":true},{"index":146,"name":"文京居民活動中心 Bunkyo Civic Center","rank":"排名第 7的文京區觀光 (共297家)","address":"東京都文京區1-16-21 Kasuga112-0003","child":0.0349650762,"latitude":35.7083399,"longitude":139.7351057,"score":114,"chosen":true
# 0
# <class 'list'>
# []

# %%
# set key to gmaps & googlemaps API
with open('../apiKey.txt') as f:
    api_key = f.readline()
    f.close
gmaps.configure(api_key=api_key)
gm = googlemaps.Client(key=api_key)
#get hotel pos. as the start & end point
hotel=(reqH['緯度'], reqH['經度'])

#read a day's POI as pandas df & loop
for d in range(len(req)):
    day=pd.read_json(req[d])

    # googlemaps direction API to determine order of POIs & output durations & distances
    waypoints=[]
    for i in range(len(day)):
        spot=(day['latitude'][i],day['longitude'][i])
        waypoints.append(spot)
    dOptRt=gm.directions(hotel,
                          hotel,
                          waypoints=waypoints,
                          optimize_waypoints=True, language='zh-TW')
    order = dOptRt[0]['waypoint_order']#list
    wpOrdered=[]
    for j in order:
        wpOrdered.append(waypoints[j])

    #print output
    routetext='讓您久等了，第'+str(d+1)+'天行程如下：\n'
    for k in range(len(day)):
        text = ('參觀'+day['name'][order[k]]+'約'+
                dOptRt[0]['legs'][k]['distance']['text']+'，景點間通勤約需'+
                dOptRt[0]['legs'][k]['duration']['text']+'\n')
        routetext+=text
    print(routetext)

    #generate the map for a day's scheduled 
#    fig = gmaps.figure()
 #   locations=[]
#    hover_text=[]
#    label=[]
#    for k in range(len(day)):
#        hover_text.append(day['name'][order[k]])
#        locations.append(wpOrdered[k])
#        label.append(str(k))
#    marker_layer = gmaps.marker_layer(
#        locations=locations,
#        hover_text=hover_text,
#        label=label
#    )
#    fig.add_layer(marker_layer)
#    fig
#    embed_minimal_html('../map/'+str(d)+'map.html', views=[fig])
# Out:
# 讓您久等了，第1天行程如下：
# 參觀晴空塔 Tokyo Skytree約1.9 公里，景點間通勤約需8 分鐘
# 參觀雷門 Nakamise Shopping Street (Kaminarimon)約3.0 公里，景點間通勤約需10 分鐘
# 參觀淺草文化觀光中心 Asakusa Culture Tourist Information Center約61 公尺，景點間通勤約需1 分鐘
# 參觀淺草 Asakusa約2.0 公里，景點間通勤約需8 分鐘
#
# 讓您久等了，第2天行程如下：
# 參觀東京迪士尼海洋樂園 Tokyo DisneySea約20.6 公里，景點間通勤約需29 分鐘
#
# 讓您久等了，第3天行程如下：
# 參觀隅田川花火大會 Sumida River Fireworks約2.5 公里，景點間通勤約需10 分鐘
# 參觀大江戶古董市場 - 東京國際論壇 Oedo Antique Market - Tokyo International Forum約7.4 公里，景點間通勤約需15 分鐘
# 參觀文京居民活動中心 Bunkyo Civic Center約7.1 公里，景點間通勤約需14 分鐘
# 參觀板橋花火節 Itabashi Fireworks約10.2 公里，景點間通勤約需17 分鐘
#
# 讓您久等了，第4天行程如下：
# 參觀伊勢丹新宿店 Isetan Shinjuku Store約16.5 公里，景點間通勤約需34 分鐘
# 參觀 Ootaguro Park約8.2 公里，景點間通勤約需24 分鐘
# 參觀東京跨海大橋 Tokyo Gate Bridge約31.8 公里，景點間通勤約需44 分鐘
# 參觀精工博物館 The Seiko Museum約16.8 公里，景點間通勤約需23 分鐘
#
# 讓您久等了，第5天行程如下：
# 參觀東京KITTE購物商城 Kitte Marunouchi約8.9 公里，景點間通勤約需20 分鐘
# 參觀陽光城60展望台 Sky Circus Sunshine60 Observatory約8.5 公里，景點間通勤約需13 分鐘
# 參觀東京馬拉松 Tokyo Marathon約15.9 公里，景點間通勤約需21 分鐘
# 參觀台場 Odaiba約17.4 公里，景點間通勤約需24 分鐘

# %%
day=pd.read_json(req[0])
day
# Out:
#    index                                               name  \
# 0      2                                         淺草 Asakusa
# 1     48          雷門 Nakamise Shopping Street (Kaminarimon)
# 2     35  淺草文化觀光中心 Asakusa Culture Tourist Information C...
# 3      8                                  晴空塔 Tokyo Skytree
#
#                    rank                           address     child  \
# 0   排名第 1的台東區觀光 (共560家)                            東京都台東區  0.008772
# 1  排名第 18的台東區觀光 (共560家)                      東京都台東區淺草1丁目3  0.004854
# 2   排名第 3的台東區觀光 (共560家)  東京都台東區2-18-9 Kaminarimon111-0034  0.004056
# 3   排名第 3的墨田區觀光 (共264家)       東京都墨田區1-1-2 Oshiage131-0045  0.016312
#
#     latitude   longitude  score  chosen
# 0  35.712574  139.780204    241    True
# 1  35.711086  139.795965    114    True
# 2  35.710649  139.796535    106    True
# 3  35.728376  139.813567     84    True

# %%
for d in range(len(req)):
    day=pd.read_json(req[d])
    #print output
    locations=[]
    hover_text=[]
    label=[]
    routetext=''
    for k in range(len(day)):
        text = (day['name'][k]+'\n大東京都會'+
                day['rank'][k]+'\n地址：'+
                day['address'][k]+'\n'*2)
        routetext+=text
        spot=(day['latitude'][k],day['longitude'][k])
        locations.append(spot)
        hover_text.append(day['name'][k])
        label.append(str(k+1))
    print(routetext,locations,hover_text,label,sep='\n')

    #generate the map for a day's scheduled 
    fig = gmaps.figure()
    marker_layer = gmaps.marker_layer(locations=locations,
                                      hover_text=hover_text,
                                      label=label
                                     )
    fig.add_layer(marker_layer)
    fig
    embed_minimal_html('../map/'+str(d)+'map.html', views=[fig])
# Out:
# 淺草 Asakusa
# 大東京都會排名第 1的台東區觀光 (共560家)
# 地址：東京都台東區
#
# 雷門 Nakamise Shopping Street (Kaminarimon)
# 大東京都會排名第 18的台東區觀光 (共560家)
# 地址：東京都台東區淺草1丁目3
#
# 淺草文化觀光中心 Asakusa Culture Tourist Information Center
# 大東京都會排名第 3的台東區觀光 (共560家)
# 地址：東京都台東區2-18-9 Kaminarimon111-0034
#
# 晴空塔 Tokyo Skytree
# 大東京都會排名第 3的墨田區觀光 (共264家)
# 地址：東京都墨田區1-1-2 Oshiage131-0045
#
#
# [(35.7125736, 139.7802043), (35.7110859, 139.7959648), (35.7106489, 139.7965348), (35.7283756, 139.8135673)]
# ['淺草 Asakusa', '雷門 Nakamise Shopping Street (Kaminarimon)', '淺草文化觀光中心 Asakusa Culture Tourist Information Center', '晴空塔 Tokyo Skytree']
# ['1', '2', '3', '4']
# 東京迪士尼海洋樂園 Tokyo DisneySea
# 大東京都會排名第 1的Maihama觀光 (共5家)
