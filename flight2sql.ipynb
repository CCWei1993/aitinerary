# %%
import pandas as pd
import numpy as np
df = pd.read_csv('csv2mySql/rndAll191031.csv', encoding='utf-8')
df
# Out:
#             airline  price  score label        cp         footnotes  \
# 0           EVA Air  10576     95   fr0  0.008983  morningafternoon
# 1    China Airlines   8306     67   fr0  0.008066  morningafternoon
# 2               JAL  12359     90   fr0  0.007282  morningafternoon
# 3           EVA Air  13156     95   fr0  0.007221  morningafternoon
# 4    China Airlines  11214     67   fr0  0.005975  morningafternoon
# ..              ...    ...    ...   ...       ...               ...
# 170  Cathay Pacific   9556     97   we5  0.010151  cp-noonafternoon
# 171         EVA Air  10886     95   we5  0.008727  cp-noonafternoon
# 172  China Airlines   9563     67   we5  0.007006  cp-noonafternoon
# 173  China Airlines  10107     67   we5  0.006629  cp-noonafternoon
# 174  China Airlines  10243     67   we5  0.006541  cp-noonafternoon
#
#                   etd       dur               eta             saEtd  ...  \
# 0    2019-07-05 15:20  03:00:00  2019-07-05 19:20  2019-07-06 13:00  ...
# ...

# %%
df.dtypes
# Out:
# airline       object
# price          int64
# score          int64
# label         object
# cp           float64
# footnotes     object
# etd           object
# dur           object
# eta           object
# saEtd         object
# saDur         object
# saEta         object
# frEtd         object
# frDur         object
# frEta         object
# thEtd         object
# thDur         object
# thEta         object
# weEtd         object
# weDur         object
# weEta         object
# tuEtd         object
# tuDur         object
# tuEta         object
# moEtd         object
# moDur         object
# moEta         object
# suEtd         object
# suDur         object
# suEta         object
# dtype: object

# %%
for i in ('dur', 'saDur', 'frDur', 'thDur', 'weDur', 'tuDur', 'moDur', 'suDur'):
    df[i]=pd.to_numeric(pd.to_timedelta(df[i])/np.timedelta64(1, 's'), downcast='integer')
df
# Out:
#             airline  price  score label        cp         footnotes  \
# 0           EVA Air  10576     95   fr0  0.008983  morningafternoon
# 1    China Airlines   8306     67   fr0  0.008066  morningafternoon
# 2               JAL  12359     90   fr0  0.007282  morningafternoon
# 3           EVA Air  13156     95   fr0  0.007221  morningafternoon
# 4    China Airlines  11214     67   fr0  0.005975  morningafternoon
# ..              ...    ...    ...   ...       ...               ...
# 170  Cathay Pacific   9556     97   we5  0.010151  cp-noonafternoon
# 171         EVA Air  10886     95   we5  0.008727  cp-noonafternoon
# 172  China Airlines   9563     67   we5  0.007006  cp-noonafternoon
# 173  China Airlines  10107     67   we5  0.006629  cp-noonafternoon
# 174  China Airlines  10243     67   we5  0.006541  cp-noonafternoon
#
#                   etd    dur               eta             saEtd  ...  \
# 0    2019-07-05 15:20  10800  2019-07-05 19:20  2019-07-06 13:00  ...
# ...

# %%
#df.to_csv('csv2mySql/rndAllDelt.csv', index=False)

# %%
for i in ('etd', 'eta', 'saEtd', 'saEta', 'frEtd', 'frEta', 'thEtd', 'thEta', 
          'weEtd', 'weEta', 'tuEtd', 'tuEta', 'moEtd', 'moEta', 'suEtd', 'suEta'):
    df[i]=pd.to_datetime(df[i])
df.dtypes
# Out:
# airline              object
# price                 int64
# score                 int64
# label                object
# cp                  float64
# footnotes            object
# etd          datetime64[ns]
# dur                   int16
# eta          datetime64[ns]
# saEtd        datetime64[ns]
# saDur                 int16
# saEta        datetime64[ns]
# frEtd        datetime64[ns]
# frDur                 int16
# frEta        datetime64[ns]
# thEtd        datetime64[ns]
# thDur                 int16
# thEta        datetime64[ns]
# weEtd        datetime64[ns]
# weDur                 int16
# weEta        datetime64[ns]
# tuEtd        datetime64[ns]
# tuDur                 int16
# tuEta        datetime64[ns]
# moEtd        datetime64[ns]
# moDur                 int16
# moEta        datetime64[ns]
# suEtd        datetime64[ns]
# suDur                 int16
# suEta        datetime64[ns]
# dtype: object

# %%
def mapping_df_types(df):
    dtypedict = {}
    for i, j in zip(df.columns, df.dtypes):
        if "object" in str(j):
            dtypedict.update({i: NVARCHAR(length=255)})
        if "float" in str(j):
            dtypedict.update({i: Float(precision=2, asdecimal=True)})
        if "int" in str(j):
            dtypedict.update({i: Integer()})
        if "datetime64[ns]" in str(j):
            dtypedict.update({i: DATETIME()})
    return dtypedict

# %%
from sqlalchemy.types import NVARCHAR, Float, Integer, DATETIME
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:iii@mysql/test".format('root', 'iii', 'host:mysql', 'test'))
conn = engine.connect()
dtypedict = mapping_df_types(df)
df.to_sql(name='flight', con=conn, if_exists='replace', index_label='id',
          dtype=dtypedict)
# Out:
# /opt/conda/lib/python3.7/site-packages/pymysql/cursors.py:170: Warning: (3720, 'NATIONAL/NCHAR/NVARCHAR implies the character set UTF8MB3, which will be replaced by UTF8MB4 in a future release. Please consider using CHAR(x) CHARACTER SET UTF8MB4 in order to be unambiguous.')
#   result = self._query(query)

# %%
import pymysql
import json

#csv 匯入 DB
try:
    engine = create_engine('mysql+pymysql://root:iii@mysql/test')
    #with engine.connect() as conn, conn.begin():
    #build connenction
    connection = pymysql.connect(host='mysql', 
                                 user='root',
                                 password='iii',
                                 charset='utf8mb4',
                                 database='test',
                                 cursorclass=pymysql.cursors.DictCursor)

    with connection.cursor() as cursor:
        sql = "USE `test`"
        cursor.execute(sql)
        sql_query = "SELECT airline,footnotes,price,label,eta,dur,etd FROM `flight` where label = 'fr1' order by etd"
        cursor.execute(sql_query)
        result = cursor.fetchall()
        for i in result:
            print(i)

except:
    connection.rollback() #Rollback the changes on error
    print('wrong sql')

finally:
    connection.close()

    #     print(result)
# Out:
# {'airline': 'EVA Air', 'footnotes': 'cp-morningnoon', 'price': 11440, 'label': 'fr1', 'eta': datetime.datetime(2019, 7, 5, 12, 0), 'dur': 11100, 'etd': datetime.datetime(2019, 7, 5, 7, 55)}
# {'airline': 'EVA Air', 'footnotes': 'cp-morningnoon', 'price': 11440, 'label': 'fr1', 'eta': datetime.datetime(2019, 7, 5, 12, 55), 'dur': 11100, 'etd': datetime.datetime(2019, 7, 5, 8, 50)}
# {'airline': 'JAL', 'footnotes': 'cp-morningnoon', 'price': 11524, 'label': 'fr1', 'eta': datetime.datetime(2019, 7, 5, 14, 0), 'dur': 10800, 'etd': datetime.datetime(2019, 7, 5, 10, 0)}
# {'airline': 'ANA', 'footnotes': 'cp-morningnoon', 'price': 13136, 'label': 'fr1', 'eta': datetime.datetime(2019, 7, 5, 14, 30), 'dur': 11400, 'etd': datetime.datetime(2019, 7, 5, 10, 20)}
# {'airline': 'Cathay Pacific', 'footnotes': 'cp-morningnoon', 'price': 9556, 'label': 'fr1', 'eta': datetime.datetime(2019, 7, 5, 16, 50), 'dur': 10800, 'etd': datetime.datetime(2019, 7, 5, 12, 50)}
# ...
